# %% [markdown]
# ## Script to plot AHN with 100 m resolution (part 2)

# %%
# Importing the libraries
import netCDF4 as nc
import matplotlib.pyplot as plt

# %%
grid = nc.Dataset('mv100.nc')
# Plot using matplotlib.pcolormesh
xx = grid.variables['x'][1000:1500]
yy = grid.variables['y'][500:1000]
zz = grid.variables['depth'][1000:1500, 500:1000]

# %%
# Plot using imshow
fig, ax = plt.subplots(1, 1, figsize=(10, 8))
plt.imshow(zz[:].T)
plt.colorbar(label='NAP Height [m]')
ax.axis('equal')
ax.axis('tight')
plt.title('Digital Elevation Model for the Nederlands')
plt.xlabel('X-RD [km]')
plt.ylabel('Y-RD [km]')
plt.clim(-50,40)

# %%
# Plot using matplotlib.pcolormesh
fig, ax = plt.subplots(1, 1, figsize=(10, 8))
cmap = plt.get_cmap('terrain')
plt.pcolormesh(xx[:] / 1000, yy[:] / 1000, zz[:].T, shading='flat',cmap=cmap)
plt.colorbar(label='NAP Height [m]')
ax.axis('equal')
ax.axis('tight')
plt.title('Digital Elevation Model for the Nederlands')
plt.xlabel('X-RD [km]')
plt.ylabel('Y-RD [km]')
plt.clim(-50,40)

# %%
# Plot using matplotlib.pcolormesh
fig, ax = plt.subplots(1, 1, figsize=(10, 8))
cmap = plt.get_cmap('terrain')
plt.pcolormesh(xx[:] / 1000, yy[:] / 1000, zz[:].T, shading='gouraud',cmap=cmap)
plt.colorbar(label='NAP Height [m]')
ax.axis('equal')
ax.axis('tight')
plt.title('Digital Elevation Model for the Nederlands')
plt.xlabel('X-RD [km]')
plt.ylabel('Y-RD [km]')
plt.clim(-50,40)

# %%
# 3D plot (better visualised in an IDE rather than Notebook)
# %matplotlib notebook
fig, ax = plt.subplots(1, 1, figsize=(10, 8))
ax = fig.gca(projection='3d')
cset = ax.contourf(xx[:]/1000, yy[:]/1000, zz[:].T/10, cmap='terrain')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1000">
# C:\Python37\lib\site-packages\ipykernel_launcher.py:4: UserWarning: Requested projection is different from current axis projection, creating new axis with requested projection.
#   after removing the cwd from sys.path.

# %%
fig, ax = plt.subplots(1, 1, figsize=(10, 8))
ax = fig.gca(projection='3d')
X, Y = np.meshgrid(xx, yy)
cset = ax.plot_surface(X[:]/1000, Y[:]/1000, zz[:].T/10, cmap='jet')
cset = ax.contour3D(X[:]/1000, Y[:]/1000, zz[:].T/10, cmap='jet')

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1000">
# C:\Python37\lib\site-packages\ipykernel_launcher.py:2: UserWarning: Requested projection is different from current axis projection, creating new axis with requested projection.
